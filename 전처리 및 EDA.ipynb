# %% [markdown]
# ## 데이터 전처리 및 EDA

# %% [markdown]
# #### 라이브러리 불러오기

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# Out:
# C:\Users\mcdor\AppData\Roaming\Python\Python311\site-packages\pandas\core\arrays\masked.py:60: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (

# %% [markdown]
# #### 데이터 불러오기

# %%
df=pd.read_csv("C:/Users/mcdor/Desktop/통계모델링및컨설팅1/프로젝트/Telecom_customer churn.csv")
df
# Out:
#        rev_Mean  mou_Mean  totmrc_Mean  da_Mean  ovrmou_Mean  ovrrev_Mean  \
# 0       23.9975    219.25       22.500   0.2475         0.00          0.0
# 1       57.4925    482.75       37.425   0.2475        22.75          9.1
# 2       16.9900     10.25       16.990   0.0000         0.00          0.0
# 3       38.0000      7.50       38.000   0.0000         0.00          0.0
# 4       55.2300    570.50       71.980   0.0000         0.00          0.0
# ...         ...       ...          ...      ...          ...          ...
# 99995       NaN       NaN          NaN      NaN          NaN          NaN
# 99996       NaN       NaN          NaN      NaN          NaN          NaN
# 99997       NaN       NaN          NaN      NaN          NaN          NaN
# 99998       NaN       NaN          NaN      NaN          NaN          NaN
# 99999       NaN       NaN          NaN      NaN          NaN          NaN
#
#        vceovr_Mean  datovr_Mean  roam_Mean  change_mou  ...  forgntvl  ethnic  \
# ...

# %% [markdown]
# #### 변수 설명
# 컬럼 설명
# 1. rev_Mean: 고객의 평균 수익(Revenue)
# 2. mou_Mean: 고객의 평균 통화 시간 (Minutes of Use)
# 3. totmrc_Mean: 고객의 평균 총 월 요금 (Total Monthly Charges)
# 4. da_Mean: 고객의 평균 데이터 사용량 (Data Usage)
# 5. ovrmou_Mean: 초과 통화 시간 평균 (Overage Minutes of Use)
# 6. ovrrev_Mean: 초과 요금 평균 (Overage Revenue)
# 7. vceovr_Mean: 음성 초과 통화 시간 평균 (Voice Overage Minutes)
# 8. datovr_Mean: 데이터 초과 사용량 평균 (Data Overage Usage)
# 9. roam_Mean: 고객의 평균 로밍 사용량
# 10. change_mou: 고객의 월별 통화 시간 변화량
# 11. change_rev: 고객의 월별 수익 변화량
# 12. drop_vce_Mean: 고객의 평균 음성 통화 중단률
# 13. drop_dat_Mean: 고객의 평균 데이터 통화 중단률
# 14. blck_vce_Mean: 고객의 평균 음성 통화 차단율
# 15. blck_dat_Mean: 고객의 평균 데이터 통화 차단율
# 16. unan_vce_Mean: 고객의 평균 음성 통화 미사용률
# 17. unan_dat_Mean: 고객의 평균 데이터 통화 미사용률
# 18. plcd_vce_Mean: 고객의 평균 발신 음성 통화 수
# 19. plcd_dat_Mean: 고객의 평균 발신 데이터 통화 수
# 20. recv_vce_Mean: 고객의 평균 수신 음성 통화 수
# 21. recv_sms_Mean: 고객의 평균 수신 SMS 수
# 22. comp_vce_Mean: 고객의 평균 음성 통화 완료 수
# 23. comp_dat_Mean: 고객의 평균 데이터 통화 완료 수
# 24. custcare_Mean: 고객 서비스 평균 호출 수
# 25. ccrndmou_Mean: 고객 서비스 통화에서의 평균 통화 시간
# 26. cc_mou_Mean: 고객 서비스 통화에서의 평균 통화 시간 (별도의 변수)
# 27. inonemin_Mean: 1분 이상 통화한 고객의 평균 통화 시간
# 28. threeway_Mean: 고객의 평균 3자 통화 수
# 29. mou_cvce_Mean: 고객의 평균 음성 통화 시간 (특정 범위나 세그먼트에 대한)
# 30. mou_cdat_Mean: 고객의 평균 데이터 통화 시간 (특정 범위나 세그먼트에 대한)
# 31. mou_rvce_Mean: 고객의 평균 음성 통화 수 (다시 연결된 통화)
# 32. owylis_vce_Mean: 고객의 음성 통화 중 "내가 사용할 수 없는" 통화 시간
# 33. mouowylisv_Mean: 고객의 음성 통화 시간 (특정 상황에서의)
# 34. iwylis_vce_Mean: 고객의 음성 통화 중 "내가 사용할 수 없는" 통화 시간
# 35. mouiwylisv_Mean: 고객의 음성 통화 시간 (다시 연결된 통화)
# 36. peak_vce_Mean: 고객의 평균 피크 시간대 음성 통화
# 37. peak_dat_Mean: 고객의 평균 피크 시간대 데이터 통화
# 38. mou_peav_Mean: 고객의 평균 피크 시간대 음성 통화 시간
# 39. mou_pead_Mean: 고객의 평균 피크 시간대 데이터 통화 시간
# 40. opk_vce_Mean: 고객의 평균 음성 통화 중 비상 상황 발생
# 41. opk_dat_Mean: 고객의 평균 데이터 통화 중 비상 상황 발생
# 42. mou_opkv_Mean: 고객의 비상 상황 발생 시 평균 음성 통화 시간
# 43. mou_opkd_Mean: 고객의 비상 상황 발생 시 평균 데이터 통화 시간
# 44. drop_blk_Mean: 고객의 평균 통화 차단율
# 45. attempt_Mean: 고객의 평균 시도된 통화 수
# 46. complete_Mean: 고객의 평균 완료된 통화 수
# 47. callfwdv_Mean: 고객의 평균 착신 전환 통화 수
# 48. callwait_Mean: 고객의 평균 대기 통화 수
# 49. churn: 고객의 이탈 여부 (1 = 이탈, 0 = 비이탈)
# 50. months: 고객이 텔레콤 서비스에 가입한 기간(개월 수)
# 51. uniqsubs: 고객이 사용하는 유니크 구독 서비스 수
# 52. actvsubs: 고객이 활성화한 구독 서비스 수
# 53. new_cell: 신규 고객인지 여부
# 54. crclscod: 특정 고객 세그먼트 코드
# 55. asl_flag: 고객이 텔레콤 서비스의 특정 유형을 사용하는지 여부
# 56. totcalls: 고객의 총 통화 수
# 57. totmou: 고객의 총 통화 시간
# 58. totrev: 고객의 총 수익
# 59. adjrev: 조정된 총 수익
# 60. adjmou: 조정된 총 통화 시간
# 61. adjqty: 조정된 총 수량
# 62. avgrev: 고객의 평균 수익
# 63. avgmou: 고객의 평균 통화 시간
# 64. avgqty: 고객의 평균 수량
# 65. avg3mou: 최근 3개월 평균 통화 시간
# 66. avg3qty: 최근 3개월 평균 사용량량
# 67. avg3rev: 최근 3개월 평균 수익
# 68. avg6mou: 최근 6개월 평균 통화 시간
# 69. avg6qty: 최근 6개월 평균 사용량
# 70. avg6rev: 최근 6개월 평균 수익
# 71. prizm_social_one: 고객의 사회적 프로필(사회적 계층)
# 72. area: 고객이 거주하는 지역
# 73. dualband: 듀얼 밴드 휴대폰 사용 여부
# 74. refurb_new: 새로 구매한 휴대폰 여부
# 75. hnd_price: 휴대폰 가격
# 76. phones: 고객이 보유한 휴대폰 수
# 77. models: 고객이 보유한 모델 수
# 78. hnd_webcap: 휴대폰의 웹 기능 여부
# 79. truck: 고객의 트럭 소유 여부
# 80. rv: 고객의 RV 소유 여부
# 81. ownrent: 고객의 집 소유 여부 (소유/임대)
# 82. lor: 고객의 집 위치 유형
# 83. dwlltype: 고객의 주택 유형
# 84. marital: 고객의 결혼 여부
# 85. adults: 가구 내 성인 수
# 86. infobase: 고객의 정보베이스
# 87. income: 고객의 연간 수입
# 88. numbcars: 고객의 자동차 수
# 89. HHstatin: 가구의 사회적 상태
# 90. dwllsize: 고객의 주택 크기
# 91. forgntvl: 고객의 해외 여행 여부
# 92. ethnic: 고객의 민족
# 93. kid0_2: 0-2세 자녀 수
# 94. kid3_5: 3-5세 자녀 수
# 95. kid6_10: 6-10세 자녀 수
# 96. kid11_15: 11-15세 자녀 수
# 97. kid16_17: 16-17세 자녀 수
# 98. creditcd: 고객의 신용 코드
# 99. eqpdays: 고객의 장비 사용 일수
# 100. Customer_ID: 고객의 고유 ID

# %% [markdown]
# #### 필요없는 컬럼 제거(주관적으로 처리, 100개 -> 75개): 일단은 gpt한테 물어봐서 처리한 부분이라, 컬럼 하나하나 자세하게 봐야한다.

# %% [markdown]
# #### 제거 할 컬럼 리스트

# %%
index = [
    53, 74, 75, 76, 77, 78, 79, 80, 81, 82, 83, 84, 85, 87, 88, 89, 
    90, 91, 92, 93, 94, 95, 96, 97, 99
]

df= df.drop(df.columns[index], axis=1)
df
# Out:
#        rev_Mean  mou_Mean  totmrc_Mean  da_Mean  ovrmou_Mean  ovrrev_Mean  \
# 0       23.9975    219.25       22.500   0.2475         0.00          0.0
# 1       57.4925    482.75       37.425   0.2475        22.75          9.1
# 2       16.9900     10.25       16.990   0.0000         0.00          0.0
# 3       38.0000      7.50       38.000   0.0000         0.00          0.0
# 4       55.2300    570.50       71.980   0.0000         0.00          0.0
# ...         ...       ...          ...      ...          ...          ...
# 99995       NaN       NaN          NaN      NaN          NaN          NaN
# 99996       NaN       NaN          NaN      NaN          NaN          NaN
# 99997       NaN       NaN          NaN      NaN          NaN          NaN
# 99998       NaN       NaN          NaN      NaN          NaN          NaN
# 99999       NaN       NaN          NaN      NaN          NaN          NaN
#
#        vceovr_Mean  datovr_Mean  roam_Mean  change_mou  ...  avg3rev  avg6mou  \
# ...

# %% [markdown]
# #### 결측치 제거(논리적 증거 필요)

# %%
missing_data = df.isnull().sum()
missing_data
# Out:
# rev_Mean         357
# mou_Mean         357
# totmrc_Mean      357
# da_Mean          357
# ovrmou_Mean      357
#                ...
# area              40
# dualband           1
# refurb_new         1
# income         25436
# eqpdays            1
# Length: 75, dtype: int64

# %%
# 결측치가 있는 열의 이름을 뽑는 코드
missing_columns = df.columns[df.isnull().any()].tolist()

# 결측치가 있는 열의 갯수 세기
missing_column_count = df.columns[df.isnull().any()].shape[0]

# 결과 출력
print("결측치가 있는 열:", missing_columns, "\n 결측치가 있는 열의 갯수:", missing_column_count)
# Out:
# 결측치가 있는 열: ['rev_Mean', 'mou_Mean', 'totmrc_Mean', 'da_Mean', 'ovrmou_Mean', 'ovrrev_Mean', 'vceovr_Mean', 'datovr_Mean', 'roam_Mean', 'change_mou', 'change_rev', 'avg6mou', 'avg6qty', 'avg6rev', 'prizm_social_one', 'area', 'dualband', 'refurb_new', 'income', 'eqpdays']
#  결측치가 있는 열의 갯수: 20

# %% [markdown]
# #### 결측치 있는 열 컬럼 설명
# **1 rev_Mean: 고객의 평균 수익(Revenue) -> 결측치 중앙값 보간 예정<br>**
# **2 mou_Mean: 고객의 평균 통화 시간 (Minutes of Use) -> 결측치 중앙값 보간 예정**<br>
# 3 totmrc_Mean: 고객의 평균 총 월 요금 (Total Monthly Charges)<br>
# 4 da_Mean: 고객의 평균 데이터 사용량 (Data Usage)<br>
# 5 ovrmou_Mean: 초과 통화 시간 평균 (Overage Minutes of Use)<br>
# 6 ovrrev_Mean: 초과 요금 평균 (Overage Revenue)<br>
# 7 vceovr_Mean: 음성 초과 통화 시간 평균 (Voice Overage Minutes)<br>
# 8 datovr_Mean: 데이터 초과 사용량 평균 (Data Overage Usage)<br>
# **9 roam_Mean: 고객의 평균 로밍 사용량-> 열 자체 제거 예정<br>**
# **10 change_mou: 고객의 월별 통화 시간 변화량-> 결측치 평균 보간 예정**<br>
# **11 change_rev: 고객의 월별 수익 변화량 -> 결측치 제거 예정**<br>
# **68 avg6mou: 최근 6개월 평균 통화 시간 -> 결측치 중앙값 보간 예정 # 그래프 쌍봉이루고 있음** <br>
# **69 avg6qty: 최근 6개월 평균 사용량-> 결측치 중앙값 보간 예정 # chrun=1일 경우 어떤 특정 값에서 매우 빈도가 높음<br>**
# **70 avg6rev: 최근 6개월 평균 수익->결측치 중앙값 보간 예정<br>**
# **71 prizm_social_one: 고객의 사회적 프로필(사회적 계층) -> 열 자체 제거 예정**<br>
# 72 area: 고객이 거주하는 지역<br>
# 73 dualband: 듀얼 밴드 휴대폰 사용 여부<br>
# 74 refurb_new: 새로 구매한 휴대폰 여부<br>
# **87 income: 고객의 연간 수입-> 잠깐 보류<br>**
# 99 eqpdays: 고객의 장비 사용 일수

# %% [markdown]
# #### 결측치 열 시각화

# %%
# 결측치 시각화 함수
def visualize_missing_data(df):
    # 결측치 비율을 계산
    missing_data = df.isnull().mean() * 100
    
    # 결측치가 0% 이상인 컬럼만 필터링
    missing_data = missing_data[missing_data > 0]
    
    # 결측치 비율을 내림차순으로 정렬
    missing_data = missing_data.sort_values(ascending=False)

    # 한 번에 너무 많은 그래프가 나오지 않도록 쪼개서 출력
    num_plots = len(missing_data)
    cols_per_plot = 5  # 한 플롯에 표시할 열 개수
    num_rows = int(np.ceil(num_plots / cols_per_plot))  # 필요한 행 수 계산 (정수로 변환)
    
    # 그리드 설정
    plt.figure(figsize=(15, num_rows * 3))  # 적절한 크기로 설정
    
    for i, (col, missing) in enumerate(missing_data.items()):
        plt.subplot(num_rows, cols_per_plot, i + 1)
        sns.barplot(x=[col], y=[missing], color='red')  # 결측치 비율을 bar로 표시
        plt.title(f'{col}: {missing:.2f}% Missing')
        plt.ylim(0, 100)  # y축 범위를 0-100으로 설정
    
    plt.tight_layout()  # 그래프 간격 조정
    plt.show()

# 예시 데이터프레임에서 결측치 시각화 호출
visualize_missing_data(df)
# Out:
# c:\ProgramData\anaconda2\Lib\site-packages\seaborn\_oldcore.py:1765: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   order = pd.unique(vector)
# c:\ProgramData\anaconda2\Lib\site-packages\seaborn\categorical.py:645: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   g_vals = grouped_vals.get_group(g)
# c:\ProgramData\anaconda2\Lib\site-packages\seaborn\_oldcore.py:1765: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   order = pd.unique(vector)
# ...

# %% [markdown]
# #### income EDA

# %%
import seaborn as sns

# 결측치 제거
df_filtered = df.dropna(subset=['income', 'churn'])

# Churn 조건으로 나누기
income_0 = df_filtered[df_filtered['churn'] == 0]['income']
income_1 = df_filtered[df_filtered['churn'] == 1]['income']

# 카운트 플롯 추가
plt.figure(figsize=(12, 5))

# Churn = 0 카운트 플롯
plt.subplot(1, 2, 1)
sns.countplot(x=income_0, palette='Blues')
plt.title('Income Distribution (Churn = 0)')
plt.xlabel('Income')
plt.ylabel('Count')

# Churn = 1 카운트 플롯
plt.subplot(1, 2, 2)
sns.countplot(x=income_1, palette='Reds')
plt.title('Income Distribution (Churn = 1)')
plt.xlabel('Income')
plt.ylabel('Count')

plt.tight_layout()
plt.show()

# %% [markdown]
#  income 변수 결측치 매우 많음.-> 이 결측치는 mean이나 mod같은 통계량으로 대체하기 힘들기 때문에 제거하는게 좋아 보인다.

# %%
df = df[df['income'].notna()]
df
# Out:
#        rev_Mean  mou_Mean  totmrc_Mean  da_Mean  ovrmou_Mean  ovrrev_Mean  \
# 0       23.9975    219.25       22.500   0.2475         0.00          0.0
# 1       57.4925    482.75       37.425   0.2475        22.75          9.1
# 2       16.9900     10.25       16.990   0.0000         0.00          0.0
# 3       38.0000      7.50       38.000   0.0000         0.00          0.0
# 4       55.2300    570.50       71.980   0.0000         0.00          0.0
# ...         ...       ...          ...      ...          ...          ...
# 99994       NaN       NaN          NaN      NaN          NaN          NaN
# 99995       NaN       NaN          NaN      NaN          NaN          NaN
# 99996       NaN       NaN          NaN      NaN          NaN          NaN
# 99997       NaN       NaN          NaN      NaN          NaN          NaN
# 99999       NaN       NaN          NaN      NaN          NaN          NaN
#
#        vceovr_Mean  datovr_Mean  roam_Mean  change_mou  ...  avg3rev  avg6mou  \
# ...

# %% [markdown]
# #### prime_social_one EDA

# %%
import seaborn as sns

# 결측치 제거
df_filtered = df.dropna(subset=['prizm_social_one', 'churn'])

# Churn 조건으로 나누기
prizm_0 = df_filtered[df_filtered['churn'] == 0]['prizm_social_one']
prizm_1 = df_filtered[df_filtered['churn'] == 1]['prizm_social_one']

# 카운트 플롯 추가
plt.figure(figsize=(12, 5))

# Churn = 0 카운트 플롯
plt.subplot(1, 2, 1)
sns.countplot(x=prizm_0, palette='Blues')
plt.title('Prizm Social One Distribution (Churn = 0)')
plt.xlabel('Prizm Social One')
plt.ylabel('Count')

# Churn = 1 카운트 플롯
plt.subplot(1, 2, 2)
sns.countplot(x=prizm_1, palette='Reds')
plt.title('Prizm Social One Distribution (Churn = 1)')
plt.xlabel('Prizm Social One')
plt.ylabel('Count')

plt.tight_layout()
plt.show()

# %% [markdown]
# U= Upper(상류층), T = Top(상위 계층), S= Standard(표준 계층), C = Central(중앙 계층), R = Regional(지역 사회의 특정 계층)
# -> 하위층 관련된 값이 없어서 분석이 무의미해보인다. 이 열도 제거하는게 좋아보인다.

# %% [markdown]
# #### avg6rev EDA

# %%
import seaborn as sns

# 결측치 제거
df_filtered = df.dropna(subset=['avg6rev', 'churn'])

# Churn 조건으로 나누기
avg6rev_0 = df_filtered[df_filtered['churn'] == 0]['avg6rev']
avg6rev_1 = df_filtered[df_filtered['churn'] == 1]['avg6rev']

# 카운트 플롯 추가
plt.figure(figsize=(12, 5))

# Churn = 0 카운트 플롯
plt.subplot(1, 2, 1)
sns.countplot(x=avg6rev_0, palette='Blues')
plt.title('avg6rev Distribution (Churn = 0)')
plt.xlabel('avg6rev')
plt.ylabel('Count')

# Churn = 1 카운트 플롯
plt.subplot(1, 2, 2)
sns.countplot(x=avg6rev_1, palette='Reds')
plt.title('avg6rev Distribution (Churn = 1)')
plt.xlabel('avg6rev')
plt.ylabel('Count')

plt.tight_layout()
plt.show()

# %% [markdown]
#  서로 비슷한 그래프 모양을 이루는것을 보아 이 컬럼은 큰 의미는 없어보인다. 그리고 그래프가 left-skewed이므로  결측치를 중앙값으로 보간한다. 그리고 양 그래프 둘다 쌍봉을 이루고 있는데 저 지점은 주의깊게 봐야할 것 같다.

# %% [markdown]
# #### avg6qty EDA

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# 결측치 제거
df_filtered = df.dropna(subset=['avg6qty', 'churn'])

# Churn 조건으로 나누기
avg6qty_0 = df_filtered[df_filtered['churn'] == 0]['avg6qty']
avg6qty_1 = df_filtered[df_filtered['churn'] == 1]['avg6qty']

# 카운트 플롯
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
sns.countplot(x=avg6qty_0, palette='Blues')
plt.title('avg6qty Distribution (Churn = 0)')
plt.xlabel('avg6qty')
plt.ylabel('Count')

plt.subplot(1, 2, 2)
sns.countplot(x=avg6qty_1, palette='Reds')
plt.title('avg6qty Distribution (Churn = 1)')
plt.xlabel('avg6qty')
plt.ylabel('Count')

plt.tight_layout()
plt.show()

# %% [markdown]
# 비슷한 분포를 띄고 있지만 churn=1경우 한 부분에서 count 수가 엄청나게 많은 것을 알 수 있다. 이 점은 인지하고, 그래프가 left-skewed 형태이므로 결측치를 중앙값으로 보간한다.

# %% [markdown]
# #### avg6mou EDA

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# 결측치 제거
df_filtered = df.dropna(subset=['avg6mou', 'churn'])

# Churn 조건으로 나누기
avg6mou_0 = df_filtered[df_filtered['churn'] == 0]['avg6mou']
avg6mou_1 = df_filtered[df_filtered['churn'] == 1]['avg6mou']

# 카운트 플롯
plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
sns.countplot(x=avg6mou_0, palette='Blues')
plt.title('avg6mou Distribution (Churn = 0)')
plt.xlabel('avg6mou')
plt.ylabel('Count')

plt.subplot(1, 2, 2)
sns.countplot(x=avg6mou_1, palette='Reds')
plt.title('avg6mou Distribution (Churn = 1)')
plt.xlabel('avg6mou')
plt.ylabel('Count')

plt.tight_layout()
plt.show()

# %% [markdown]
# 그래프 둘다 비슷한 형태이고 특별한 부분은 발견이 안된다. 그리고 그래프가 left-skewed이므로 중앙값으로 결측치를 대체한다.

# %%
import seaborn as sns

# 결측치 제거
df_filtered = df.dropna(subset=['income', 'churn'])

# Churn 조건으로 나누기
income_0 = df_filtered[df_filtered['churn'] == 0]['income']
income_1 = df_filtered[df_filtered['churn'] == 1]['income']

# 카운트 플롯 추가
plt.figure(figsize=(12, 5))

# Churn = 0 카운트 플롯
plt.subplot(1, 2, 1)
sns.countplot(x=income_0, palette='Blues')
plt.title('Income Distribution (Churn = 0)')
plt.xlabel('Income')
plt.ylabel('Count')

# Churn = 1 카운트 플롯
plt.subplot(1, 2, 2)
sns.countplot(x=income_1, palette='Reds')
plt.title('Income Distribution (Churn = 1)')
plt.xlabel('Income')
plt.ylabel('Count')

plt.tight_layout()
plt.show()

# %% [markdown]
# #### change_rev EDA

# %%
import seaborn as sns

# 결측치 제거
df_filtered = df.dropna(subset=['change_rev', 'churn'])

# Churn 조건으로 나누기
change_0 = df_filtered[df_filtered['churn'] == 0]['change_rev']
change_1 = df_filtered[df_filtered['churn'] == 1]['change_rev']

# 히스토그램 밀도 추정
plt.figure(figsize=(12, 5))

# Churn = 0 히스토그램
plt.subplot(1, 2, 1)
plt.hist(change_0, bins=50, color='skyblue', edgecolor='black', alpha=0.7, density=True)
plt.title('Change Rev Distribution (Churn = 0)')
plt.xlabel('Change Rev')
plt.ylabel('Density')

# Churn = 1 히스토그램
plt.subplot(1, 2, 2)
plt.hist(change_1, bins=50, color='salmon', edgecolor='black', alpha=0.7, density=True)
plt.title('Change Rev Distribution (Churn = 1)')
plt.xlabel('Change Rev')
plt.ylabel('Density')

plt.tight_layout()
plt.show()

# 상자 그림(Box plot) 추가
plt.figure(figsize=(8, 6))
sns.boxplot(x='churn', y='change_rev', data=df_filtered, palette='coolwarm')
plt.title('Box Plot of Change Rev by Churn')
plt.xlabel('Churn')
plt.ylabel('Change Rev')
plt.show()

# %% [markdown]
#  고객이 이탈한 경우(chrun==1), change rev 수치가 음수인 경우가 더 많다. 따라서 이 컬럼은 중요해보이고 비슷한 값이더라도 그 값이 음수인지 양수인지의 차이가 매우 클 것 같으므로
# 결측치를 보간하긴 어렵다. 따라서 결측치를 제거한다.

# %% [markdown]
# #### change_mou EDA

# %%
import seaborn as sns
import matplotlib.pyplot as plt

df_filtered = df.dropna(subset=['change_mou', 'churn'])

change_mou_0 = df_filtered[df_filtered['churn'] == 0]['change_mou']
change_mou_1 = df_filtered[df_filtered['churn'] == 1]['change_mou']

plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
sns.countplot(x=change_mou_0, palette='Blues')
plt.title('change_mou Distribution (Churn = 0)')
plt.xlabel('change_mou')
plt.ylabel('Count')

plt.subplot(1, 2, 2)
sns.countplot(x=change_mou_1, palette='Reds')
plt.title('change_mou Distribution (Churn = 1)')
plt.xlabel('change_mou')
plt.ylabel('Count')

plt.tight_layout()
plt.show()

# %% [markdown]
# 두 그래프 모두 정규분포 모양을 지니고 있다. 결측치를 평균으로 보간한다.

# %% [markdown]
# #### mou_Mean EDA

# %%
df_filtered = df.dropna(subset=['mou_Mean', 'churn'])

mou_Mean_0 = df_filtered[df_filtered['churn'] == 0]['mou_Mean']
mou_Mean_1 = df_filtered[df_filtered['churn'] == 1]['mou_Mean']

plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
sns.countplot(x=mou_Mean_0, palette='Blues')
plt.title('mou_Mean Distribution (Churn = 0)')
plt.xlabel('mou_Mean')
plt.ylabel('Count')

plt.subplot(1, 2, 2)
sns.countplot(x=mou_Mean_1, palette='Reds')
plt.title('mou_Mean Distribution (Churn = 1)')
plt.xlabel('mou_Mean')
plt.ylabel('Count')

plt.tight_layout()
plt.show()

# %% [markdown]
# 두 그래프 left-skewed이므로 중앙값으로 대체한다.

# %% [markdown]
# #### rev_Mean EDA

# %%
# 결측치 제거
df_filtered = df.dropna(subset=['rev_Mean', 'churn'])

# Churn 조건으로 나누기
rev_0 = df_filtered[df_filtered['churn'] == 0]['rev_Mean']
rev_1 = df_filtered[df_filtered['churn'] == 1]['rev_Mean']

# 히스토그램 밀도 추정
plt.figure(figsize=(12, 5))

# Churn = 0 히스토그램
plt.subplot(1, 2, 1)
plt.hist(rev_0, bins=50, color='skyblue', edgecolor='black', alpha=0.7, density=True)
plt.title('Rev_Mean Distribution (Churn = 0)')
plt.xlabel('Rev_Mean')
plt.ylabel('Density')

# Churn = 1 히스토그램
plt.subplot(1, 2, 2)
plt.hist(rev_1, bins=50, color='salmon', edgecolor='black', alpha=0.7, density=True)
plt.title('Rev_Mean Distribution (Churn = 1)')
plt.xlabel('Rev_Mean')
plt.ylabel('Density')

plt.tight_layout()
plt.show()

# 상자 그림(Box plot) 추가
plt.figure(figsize=(8, 6))
sns.boxplot(x='churn', y='rev_Mean', data=df_filtered, palette='coolwarm')
plt.title('Box Plot of Rev_Mean by Churn')
plt.xlabel('Churn')
plt.ylabel('Rev_Mean')
plt.show()

# %% [markdown]
# left_skewed이므로 중앙값으로 대체한다.

# %% [markdown]
# #### roam_Mean EDA

# %%
# 결측치 제거
df_filtered = df.dropna(subset=['roam_Mean', 'churn'])

# Churn 조건으로 나누기
roam_0 = df_filtered[df_filtered['churn'] == 0]['roam_Mean']
roam_1 = df_filtered[df_filtered['churn'] == 1]['roam_Mean']

# 히스토그램 플롯
plt.figure(figsize=(12, 5))

# Churn = 0 히스토그램
plt.subplot(1, 2, 1)
sns.histplot(roam_0, bins=50, color='skyblue', kde=False)
plt.title('roam_Mean Distribution (Churn = 0)')
plt.xlabel('roam_Mean')
plt.ylabel('Count')

# Churn = 1 히스토그램
plt.subplot(1, 2, 2)
sns.histplot(roam_1, bins=50, color='salmon', kde=False)
plt.title('roam_Mean Distribution (Churn = 1)')
plt.xlabel('roam_Mean')
plt.ylabel('Count')

plt.tight_layout()
plt.show()
# Out:
# c:\ProgramData\anaconda2\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\ProgramData\anaconda2\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %% [markdown]
# 로밍 사용량이 0인 경우가 대다수다. 이 부분은 로밍사용량이 0이거나 아니면 0이 아닌 것으로 나누어 분류하는게 좋아보인다.

# %%
# 결측치 제거
df_filtered = df.dropna(subset=['roam_Mean', 'churn'])

# roam_Mean이 0인 경우와 0이 아닌 경우로 나누기
roam_zero = df_filtered[df_filtered['roam_Mean'] == 0]
roam_nonzero = df_filtered[df_filtered['roam_Mean'] != 0]

# 그래프
plt.figure(figsize=(12, 5))

# roam_Mean == 0일 때 churn 분포
plt.subplot(1, 2, 1)
sns.countplot(x='churn', data=roam_zero, palette='Blues')
plt.title('Churn Distribution (roam_Mean = 0)')
plt.xlabel('Churn')
plt.ylabel('Count')
plt.xticks([0, 1], ['No Churn', 'Churn'])

# roam_Mean != 0일 때 churn 분포
plt.subplot(1, 2, 2)
sns.countplot(x='churn', data=roam_nonzero, palette='Reds')
plt.title('Churn Distribution (roam_Mean ≠ 0)')
plt.xlabel('Churn')
plt.ylabel('Count')
plt.xticks([0, 1], ['No Churn', 'Churn'])

plt.tight_layout()
plt.show()

# %% [markdown]
# 그래프를 봐서는 로밍 사용량이 churn에 영향을 끼치진 않는 것으로 보인다. 열 자체를 제거한다.
